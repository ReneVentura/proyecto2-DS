# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima.utils import ndiffs
from statsmodels.graphics.tsaplots import acf, plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_predict
from sklearn.model_selection import train_test_split
import scipy.stats as stats
import statsmodels.api as sm
import datetime

# %%
DATASETALBUMS = pd.read_csv("datasetsalbums.csv" ,sep = '\t')
DATASETARTIST = pd.read_csv("datasetsartists.csv" ,sep = '\t')
DATASETTRACKS = pd.read_csv("datasetstracks.csv" ,sep = '\t')
DATASETTRAIN_INTERACTION = pd.read_csv("datasetstrain_interactions.csv",sep = '\t')
DATASETTRAIN_PLAYLIST = pd.read_csv("datasetstrain_playlists.csv",sep = '\t')

# %%
DATASETALBUMS
# Out:
#           alid                             album_uri  \
# 0            0  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1            1  spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2            2  spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3            3  spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4            4  spotify:album:6NmFmPX56pcLBOFMhIiKvF
# ...        ...                                   ...
# 734679  734679  spotify:album:6SOk4wEfFaeReDjgZVHgd8
# 734680  734680  spotify:album:6Muigto0lAY11yHT1IwRD4
# 734681  734681  spotify:album:5n5KszdWrFsFJjCgxyL7yq
# 734682  734682  spotify:album:2S3nz60ee9Qg1NwUG0Me0w
# 734683  734683  spotify:album:60Nz1KLyK6hhOhTZjlGZQI
#
#                                                album_name
# 0                                            The Cookbook
# 1                                             In The Zone
# 2            Dangerously In Love (Alben für die Ewigkeit)
# 3                                               Justified
# 4                                                Hot Shot
# ...                                                   ...
# 734679                    Moby Dick read by Hayward Morse
# 734680  A Journey to the Centre of the Earth (Jules Ve...
# 734681                                        Sol y playa
# 734682                        Quedate (Mambo Kings Remix)
# 734683                                   The Straw Theory
#
# [734684 rows x 3 columns]

# %%
DATASETARTIST
# Out:
#           arid                             artist_uri  \
# 0            0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1            1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2            2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3            3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4            4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...        ...                                    ...
# 295855  295855  spotify:artist:1hrgi9UexDilauxUQkEeR7
# 295856  295856  spotify:artist:1LycqtoIlBREAi3RzKGECM
# 295857  295857  spotify:artist:3pwMDLDaW2B7vUNAAbv8M8
# 295858  295858  spotify:artist:0IvkFOzIGibOreT4Ez9Yyj
# 295859  295859  spotify:artist:2stBqJCSWouhEQwwW3x3RK
#
#                         artist_name
# 0                     Missy Elliott
# 1                    Britney Spears
# 2                           Beyoncé
# 3                 Justin Timberlake
# 4                            Shaggy
# ...                             ...
# 295855               Leticia Dolera
# 295856                  John Pariva
# 295857             Hermann Melville
# 295858  Eternal Classic Audio Books
# 295859                 Straw Theory
#
# [295860 rows x 3 columns]

# %%
DATASETTRACKS
# Out:
#              tid    arid    alid                             track_uri  \
# 0              0       0       0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1              1       1       1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2              2       2       2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3              3       3       3  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4              4       4       4  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...          ...     ...     ...                                   ...
# 2262287  2262287   93486  229637  spotify:track:2aOoiTTV0OR8DYxCk8o0JR
# 2262288  2262288   93486  229637  spotify:track:1Uo65qTxnCg1N1X00lgcjr
# 2262289  2262289   93486  229637  spotify:track:5uEE5tii66I0cC7kZ7IMxE
# 2262290  2262290   93486  229637  spotify:track:6A1RfnrMdxb24OYllzzTUX
# 2262291  2262291  295859  734683  spotify:track:5DvykFHB6utG6Hozpt5eNK
#
#                                          track_name  duration_ms
# 0        Lose Control (feat. Ciara & Fat Man Scoop)       226863
# 1                                             Toxic       198800
# 2                                     Crazy In Love       235933
# 3                                    Rock Your Body       267266
# 4                                      It Wasn't Me       227600
# ...                                             ...          ...
# 2262287          Forevermind - Pax217 Album Version       206400
# 2262288               Shalom - Pax217 Album Version       268266
# 2262289           Free To Be - Pax217 Album Version       334280
# 2262290                Skwid - Pax217 Album Version       240453
# 2262291                                Running Thin       341933
#
# [2262292 rows x 6 columns]

# %%
DATASETTRAIN_INTERACTION
# Out:
#              pid     tid  pos
# 0              0       0    0
# 1              0       1    1
# 2              0       2    2
# 3              0       3    3
# 4              0       4    4
# ...          ...     ...  ...
# 66346423  999999   72432  105
# 66346424  999999  288294  106
# 66346425  999999  141054  107
# 66346426  999999  141039  108
# 66346427  999999   72395  109
#
# [66346428 rows x 3 columns]

# %%
DATASETTRAIN_PLAYLIST
# Out:
#            pid              name  collaborative  modified_at  num_albums  \
# 0            0        Throwbacks          False   1493424000          47
# 1            1  Awesome Playlist          False   1506556800          23
# 2            2           korean           False   1505692800          51
# 3            3               mat          False   1501027200         107
# 4            4               90s          False   1401667200          16
# ...        ...               ...            ...          ...         ...
# 999995  999995            Praise          False   1409529600          23
# 999996  999996           Worship          False   1475625600          74
# 999997  999997               Sex          False   1498176000          22
# 999998  999998                ✝️          False   1506816000           8
# 999999  999999             BANDA          False   1433116800          57
#
#         num_tracks  num_followers  num_tracks.1  num_edits  duration_ms  \
# 0               52              1            52          6     11532414
# 1               39              1            39          5     11656470
# 2               64              1            64         18     14039958
# 3              126              1           126          4     28926058
# 4               17              2            17          7      4335282
# ...            ...            ...           ...        ...          ...
# 999995          32              1            32          5      8502173
# 999996         122              1           122         12     31246908
# 999997          24              1            24          4      6015165
# 999998          11              1            11          6      2909608
# 999999         110              1           110         13     19451365
#
#         num_artists description
# 0                37         NaN
# 1                21         NaN
# 2                31         NaN
# 3                86         NaN
# 4                16         NaN
# ...             ...         ...
# 999995           11         NaN
# 999996           42         NaN
# 999997           17         NaN
# 999998            5         NaN
# 999999           26         NaN
#
# [1000000 rows x 12 columns]

# %% [markdown]
# REVISAMOS VALORES NULOS

# %%
DATASETTRAIN_PLAYLIST.isna().sum().to_frame()
DATASETTRAIN_INTERACTION.isna().sum().to_frame()
DATASETTRACKS.isna().sum().to_frame()
DATASETALBUMS.isna().sum().to_frame()
DATASETARTIST.isna().sum().to_frame()
# Out:
#              0
# arid         0
# artist_uri   0
# artist_name  4

# %%
fig1 = plt.figure(figsize=(20,10)) 
DATASETTRAIN_PLAYLIST.hist("num_tracks", bins = 6, color = "crimson")
plt.title("CANTIDAD DE CANCIONES EN PLAYLIST " )
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE CANCIONES EN PLAYLIST ')

# %%
fig1 = plt.figure(figsize=(20,10)) 
DATASETTRAIN_PLAYLIST.hist("num_albums", bins = 6, color = "crimson")
plt.title("CANTIDAD DE ALBUMS EN PLAYLIST " )
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE ALBUMS EN PLAYLIST ')

# %%
fig1 = plt.figure(figsize=(20,10)) 
DATASETTRAIN_PLAYLIST.hist("num_edits", bins = 12, color = "crimson")
plt.title("CANTIDAD DE EDITS EN PLAYLIST " )
# Out:
# Text(0.5, 1.0, 'CANTIDAD DE EDITS EN PLAYLIST ')

# %%
fig1 = plt.figure(figsize=(20,10)) 
DATASETTRACKSDIVS = DATASETTRACKS["duration_ms"].div(100)
DATASETTRACKSDIVS.hist("duration_ms", bins = 12, color = "crimson")
plt.title("DURACION DE TRACKS " )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [55], in <cell line: 3>()
#       1 fig1 = plt.figure(figsize=(20,10))
#       2 DATASETTRACKSDIVS = DATASETTRACKS["duration_ms"].div(100)
# ----> 3 DATASETTRACKSDIVS.hist("duration_ms", bins = 12, color = "crimson")
#       4 plt.title("DURACION DE TRACKS " )
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_core.py:100, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      48 """
#      49 Draw histogram of the input series using matplotlib.
#      50
#    (...)
#      97 matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      98 """
#      99 plot_backend = _get_plot_backend(backend)
# --> 100 return plot_backend.hist_series(
#     101     self,
#     102     by=by,
#     103     ax=ax,
#     104     grid=grid,
#     105     xlabelsize=xlabelsize,
#     106     xrot=xrot,
#     107     ylabelsize=ylabelsize,
#     108     yrot=yrot,
#     109     figsize=figsize,
#     110     bins=bins,
#     111     legend=legend,
#     112     **kwargs,
#     113 )
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:407, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     402     if "figure" in kwds:
#     403         raise ValueError(
#     404             "Cannot pass 'figure' when using the "
#     405             "'by' argument, since a new 'Figure' instance will be created"
#     406         )
# --> 407     axes = _grouped_hist(
#     408         self,
#     409         by=by,
#     410         ax=ax,
#     411         grid=grid,
#     412         figsize=figsize,
#     413         bins=bins,
#     414         xlabelsize=xlabelsize,
#     415         xrot=xrot,
#     416         ylabelsize=ylabelsize,
#     417         yrot=yrot,
#     418         legend=legend,
#     419         **kwds,
#     420     )
#     422 if hasattr(axes, "ndim"):
#     423     if axes.ndim == 1 and len(axes) == 1:
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:333, in _grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, legend, **kwargs)
#     330 if xrot is None:
#     331     xrot = rot
# --> 333 fig, axes = _grouped_plot(
#     334     plot_group,
#     335     data,
#     336     column=column,
#     337     by=by,
#     338     sharex=sharex,
#     339     sharey=sharey,
#     340     ax=ax,
#     341     figsize=figsize,
#     342     layout=layout,
#     343     rot=rot,
#     344 )
#     346 set_ticks_props(
#     347     axes, xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot
#     348 )
#     350 maybe_adjust_figure(
#     351     fig, bottom=0.15, top=0.9, left=0.1, right=0.9, hspace=0.5, wspace=0.3
#     352 )
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:253, in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#     246 if figsize == "default":
#     247     # allowed to specify mpl default with 'default'
#     248     raise ValueError(
#     249         "figsize='default' is no longer supported. "
#     250         "Specify figure size by tuple instead"
#     251     )
# --> 253 grouped = data.groupby(by)
#     254 if column is not None:
#     255     grouped = grouped[column]
#
# File D:\Anaconda\lib\site-packages\pandas\core\series.py:1922, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1918 axis = self._get_axis_number(axis)
#    1920 # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#    1921 # "Union[bool, NoDefault]"; expected "bool"
# -> 1922 return SeriesGroupBy(
#    1923     obj=self,
#    1924     keys=by,
#    1925     axis=axis,
#    1926     level=level,
#    1927     as_index=as_index,
#    1928     sort=sort,
#    1929     group_keys=group_keys,
#    1930     squeeze=squeeze,  # type: ignore[arg-type]
#    1931     observed=observed,
#    1932     dropna=dropna,
#    1933 )
#
# File D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File D:\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'duration_ms'
